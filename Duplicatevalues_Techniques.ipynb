# %%
import pandas as pd
import numpy as np

# %%
employee = [('Rahul', 28,'Varanasi'), ('Jyotsna', 24, 'Delhi'), ('Rahul', 28,'Varanasi'),('Jyotsna',24,'Delhi'),('Aditya',28,'Kolkata'),('Angad',26,'Delhi'),('Sandeep',40,'Delhi')]

# %%
df = pd.DataFrame(employee, columns = ['Name', 'Age', 'City'])

# %%
df
# Out:
#       Name  Age      City
# 0    Rahul   28  Varanasi
# 1  Jyotsna   24     Delhi
# 2    Rahul   28  Varanasi
# 3  Jyotsna   24     Delhi
# 4   Aditya   28   Kolkata
# 5    Angad   26     Delhi
# 6  Sandeep   40     Delhi

# %%
df[df.duplicated()]
# Out:
#       Name  Age      City
# 2    Rahul   28  Varanasi
# 3  Jyotsna   24     Delhi

# %%
df.drop_duplicates()
# Out:
#       Name  Age      City
# 0    Rahul   28  Varanasi
# 1  Jyotsna   24     Delhi
# 4   Aditya   28   Kolkata
# 5    Angad   26     Delhi
# 6  Sandeep   40     Delhi
