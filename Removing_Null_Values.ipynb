# %%
import pandas as pd
import numpy as np

# %%
my_dict = {'First' : [95,90,np.nan,100], 'Second' : [30,45,56,np.nan], 'Third' : [np.nan,34,42,76]}

# %%
df = pd.DataFrame(my_dict)

# %%
df
# Out:
#    First  Second  Third
# 0   95.0    30.0    NaN
# 1   90.0    45.0   34.0
# 2    NaN    56.0   42.0
# 3  100.0     NaN   76.0

# %%
#Remove rows that contain missing values
df1 = df.dropna()

# %%
df1
# Out:
#    First  Second  Third
# 1   90.0    45.0   34.0

# %%
#Remove columns that contain missing values
df2 = df.dropna(axis=1)

# %%
df2
# Out:
# Empty DataFrame
# Columns: []
# Index: [0, 1, 2, 3]
